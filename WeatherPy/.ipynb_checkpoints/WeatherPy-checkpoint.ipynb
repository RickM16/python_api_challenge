# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 661

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create the lists to hold relative data
cities_list= []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
# Create a base url
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Counters
city_counter = 1
set_counter = 1

print("Begin Data Retrieval")
print("------------------------")

# Create a query url for each city in the cities list to get json response
for i, city in enumerate(cities):
    
    # Group cities as sets of 50s
    if (i % 50 == 0 and i >= 50):
        set_counter += 1
        city_counter = 1
         
    # API url for each city
    query_url = url +"&q=" + city
    
    # Get json respose for each city
    response = requests.get(query_url).json()
    
    # Print the results 
    print(f"Processing Record {city_counter} of Set {set_counter} | {city}")
    
    # Increase counter
    city_counter += 1
    
   # Add the values
    try:       
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        cities_list.append(response["name"])
    except:
        print("City not found! SKIPPNIG! ")
        pass
        
print("------------------------")        
print("Completed")
# Out:
# Begin Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | hirara
# Processing Record 2 of Set 1 | anadyr
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | vaitupu
# City not found! SKIPPNIG!
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | luba
# Processing Record 8 of Set 1 | umm lajj
# Processing Record 9 of Set 1 | faanui
# Processing Record 10 of Set 1 | vaitape
# Processing Record 11 of Set 1 | saint-augustin
# Processing Record 12 of Set 1 | belyy yar
# Processing Record 13 of Set 1 | nouadhibou
# Processing Record 14 of Set 1 | sumbawa
# City not found! SKIPPNIG!
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | vostok
# Processing Record 17 of Set 1 | nizhneyansk
# City not found! SKIPPNIG!
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | vardo
# Processing Record 21 of Set 1 | mae hong son
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | havoysund
# Processing Record 24 of Set 1 | maltahohe
# Processing Record 25 of Set 1 | margate
# Processing Record 26 of Set 1 | denpasar
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | lafia
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | coquimbo
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | lima
# Processing Record 38 of Set 1 | toowoomba
# Processing Record 39 of Set 1 | dwarahat
# Processing Record 40 of Set 1 | klyuchi
# Processing Record 41 of Set 1 | bereznik
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | victoria
# Processing Record 44 of Set 1 | marawi
# Processing Record 45 of Set 1 | maraa
# Processing Record 46 of Set 1 | ninghai
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | sistranda
# Processing Record 49 of Set 1 | faya
# Processing Record 50 of Set 1 | torbay
# Processing Record 1 of Set 2 | puerto quijarro
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | zaysan
# Processing Record 4 of Set 2 | aklavik
# Processing Record 5 of Set 2 | koundara
# Processing Record 6 of Set 2 | pirovskoye
# Processing Record 7 of Set 2 | aguadilla
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | cidreira
# Processing Record 10 of Set 2 | khovu-aksy
# Processing Record 11 of Set 2 | shitanjing
# Processing Record 12 of Set 2 | sabzevar
# Processing Record 13 of Set 2 | dingle
# Processing Record 14 of Set 2 | kavieng
# Processing Record 15 of Set 2 | kutum
# Processing Record 16 of Set 2 | praia da vitoria
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | korla
# Processing Record 19 of Set 2 | rostaq
# City not found! SKIPPNIG!
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | taolanaro
# City not found! SKIPPNIG!
# Processing Record 24 of Set 2 | shimoda
# Processing Record 25 of Set 2 | gewane
# Processing Record 26 of Set 2 | darhan
# Processing Record 27 of Set 2 | neos oropos
# Processing Record 28 of Set 2 | samusu
# City not found! SKIPPNIG!
# Processing Record 29 of Set 2 | launceston
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found! SKIPPNIG!
# Processing Record 32 of Set 2 | port lincoln
# Processing Record 33 of Set 2 | belushya guba
# City not found! SKIPPNIG!
# Processing Record 34 of Set 2 | satitoa
# City not found! SKIPPNIG!
# Processing Record 35 of Set 2 | mitsamiouli
# Processing Record 36 of Set 2 | qaqortoq
# Processing Record 37 of Set 2 | katsuura
# Processing Record 38 of Set 2 | kirakira
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | forst
# Processing Record 42 of Set 2 | amderma
# City not found! SKIPPNIG!
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | kitami
# Processing Record 45 of Set 2 | wulanhaote
# City not found! SKIPPNIG!
# Processing Record 46 of Set 2 | rikitea
# Processing Record 47 of Set 2 | grand gaube
# Processing Record 48 of Set 2 | vaini
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | mahon
# Processing Record 2 of Set 3 | gamba
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found! SKIPPNIG!
# Processing Record 4 of Set 3 | aykhal
# Processing Record 5 of Set 3 | kahului
# Processing Record 6 of Set 3 | longyearbyen
# Processing Record 7 of Set 3 | ushuaia
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | pecanha
# Processing Record 10 of Set 3 | los llanos de aridane
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | arman
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | pisco
# Processing Record 16 of Set 3 | dunedin
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | chipinge
# Processing Record 19 of Set 3 | upernavik
# Processing Record 20 of Set 3 | castro
# Processing Record 21 of Set 3 | ranong
# Processing Record 22 of Set 3 | sao felix do xingu
# Processing Record 23 of Set 3 | shumskiy
# Processing Record 24 of Set 3 | bawku
# Processing Record 25 of Set 3 | katsiveli
# City not found! SKIPPNIG!
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | pacific grove
# Processing Record 28 of Set 3 | maiduguri
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | hendijan
# City not found! SKIPPNIG!
# Processing Record 31 of Set 3 | kalmunai
# Processing Record 32 of Set 3 | mahibadhoo
# Processing Record 33 of Set 3 | evanston
# Processing Record 34 of Set 3 | yulara
# Processing Record 35 of Set 3 | marsa matruh
# Processing Record 36 of Set 3 | ayr
# Processing Record 37 of Set 3 | marathon
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | laguna
# Processing Record 40 of Set 3 | marystown
# Processing Record 41 of Set 3 | ayan
# Processing Record 42 of Set 3 | santa marta
# Processing Record 43 of Set 3 | bolungarvik
# City not found! SKIPPNIG!
# Processing Record 44 of Set 3 | robertsport
# Processing Record 45 of Set 3 | thompson
# Processing Record 46 of Set 3 | guinope
# Processing Record 47 of Set 3 | poya
# Processing Record 48 of Set 3 | touros
# Processing Record 49 of Set 3 | sao filipe
# Processing Record 50 of Set 3 | kyra
# Processing Record 1 of Set 4 | bereda
# Processing Record 2 of Set 4 | barentsburg
# City not found! SKIPPNIG!
# Processing Record 3 of Set 4 | samarai
# Processing Record 4 of Set 4 | sisimiut
# Processing Record 5 of Set 4 | khorinsk
# Processing Record 6 of Set 4 | berlevag
# Processing Record 7 of Set 4 | mys shmidta
# City not found! SKIPPNIG!
# Processing Record 8 of Set 4 | veraval
# Processing Record 9 of Set 4 | saint george
# Processing Record 10 of Set 4 | bodden town
# Processing Record 11 of Set 4 | balabanesti
# City not found! SKIPPNIG!
# Processing Record 12 of Set 4 | binga
# Processing Record 13 of Set 4 | sept-iles
# Processing Record 14 of Set 4 | attawapiskat
# City not found! SKIPPNIG!
# Processing Record 15 of Set 4 | mattru
# Processing Record 16 of Set 4 | cockburn town
# Processing Record 17 of Set 4 | tsihombe
# City not found! SKIPPNIG!
# Processing Record 18 of Set 4 | zavallya
# Processing Record 19 of Set 4 | okhotsk
# Processing Record 20 of Set 4 | sola
# Processing Record 21 of Set 4 | baruun-urt
# Processing Record 22 of Set 4 | chagda
# City not found! SKIPPNIG!
# Processing Record 23 of Set 4 | baykit
# Processing Record 24 of Set 4 | georgetown
# Processing Record 25 of Set 4 | tasiilaq
# Processing Record 26 of Set 4 | north bend
# Processing Record 27 of Set 4 | najran
# Processing Record 28 of Set 4 | harbour breton
# Processing Record 29 of Set 4 | vila franca do campo
# Processing Record 30 of Set 4 | bunia
# Processing Record 31 of Set 4 | solnechnyy
# Processing Record 32 of Set 4 | tautira
# Processing Record 33 of Set 4 | pozo colorado
# Processing Record 34 of Set 4 | esperance
# Processing Record 35 of Set 4 | qaanaaq
# Processing Record 36 of Set 4 | monrovia
# Processing Record 37 of Set 4 | san pedro
# Processing Record 38 of Set 4 | ponta delgada
# Processing Record 39 of Set 4 | puerto ayacucho
# Processing Record 40 of Set 4 | cherskiy
# Processing Record 41 of Set 4 | san jose
# Processing Record 42 of Set 4 | nyagan
# Processing Record 43 of Set 4 | bilibino
# Processing Record 44 of Set 4 | sungaipenuh
# Processing Record 45 of Set 4 | santa vitoria do palmar
# Processing Record 46 of Set 4 | warrington
# Processing Record 47 of Set 4 | west wendover
# Processing Record 48 of Set 4 | college
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | namibe
# Processing Record 1 of Set 5 | tete
# Processing Record 2 of Set 5 | vanderhoof
# Processing Record 3 of Set 5 | koutsouras
# Processing Record 4 of Set 5 | julio de castilhos
# Processing Record 5 of Set 5 | tiksi
# Processing Record 6 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 5 | santarem
# Processing Record 8 of Set 5 | urucara
# Processing Record 9 of Set 5 | inhambane
# Processing Record 10 of Set 5 | xiaoweizhai
# Processing Record 11 of Set 5 | port macquarie
# Processing Record 12 of Set 5 | byron bay
# Processing Record 13 of Set 5 | gigmoto
# Processing Record 14 of Set 5 | abha
# Processing Record 15 of Set 5 | lipetsk
# Processing Record 16 of Set 5 | hualmay
# Processing Record 17 of Set 5 | santa luzia
# Processing Record 18 of Set 5 | kapaa
# Processing Record 19 of Set 5 | shar
# Processing Record 20 of Set 5 | itarema
# Processing Record 21 of Set 5 | ancud
# Processing Record 22 of Set 5 | guerrero negro
# Processing Record 23 of Set 5 | lobanovo
# Processing Record 24 of Set 5 | nsukka
# Processing Record 25 of Set 5 | qujing
# Processing Record 26 of Set 5 | shelburne
# Processing Record 27 of Set 5 | dawlatabad
# Processing Record 28 of Set 5 | zhangye
# Processing Record 29 of Set 5 | kitui
# Processing Record 30 of Set 5 | lavrentiya
# Processing Record 31 of Set 5 | opuwo
# Processing Record 32 of Set 5 | charagua
# Processing Record 33 of Set 5 | clyde river
# Processing Record 34 of Set 5 | salinopolis
# Processing Record 35 of Set 5 | mandalgovi
# Processing Record 36 of Set 5 | cay
# Processing Record 37 of Set 5 | charters towers
# Processing Record 38 of Set 5 | tilichiki
# Processing Record 39 of Set 5 | ambon
# Processing Record 40 of Set 5 | sakakah
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | kisangani
# Processing Record 43 of Set 5 | narsaq
# Processing Record 44 of Set 5 | qasigiannguit
# Processing Record 45 of Set 5 | saleaula
# City not found! SKIPPNIG!
# Processing Record 46 of Set 5 | valparaiso
# Processing Record 47 of Set 5 | port alfred
# Processing Record 48 of Set 5 | avera
# Processing Record 49 of Set 5 | portland
# Processing Record 50 of Set 5 | nenjiang
# Processing Record 1 of Set 6 | ratnagiri
# Processing Record 2 of Set 6 | vestmannaeyjar
# Processing Record 3 of Set 6 | deer lake
# Processing Record 4 of Set 6 | zhangjiakou
# Processing Record 5 of Set 6 | bengkulu
# Processing Record 6 of Set 6 | makakilo city
# Processing Record 7 of Set 6 | port hawkesbury
# Processing Record 8 of Set 6 | alofi
# Processing Record 9 of Set 6 | san patricio
# Processing Record 10 of Set 6 | talara
# Processing Record 11 of Set 6 | havre-saint-pierre
# Processing Record 12 of Set 6 | sungairaya
# Processing Record 13 of Set 6 | jibuti
# Processing Record 14 of Set 6 | salalah
# Processing Record 15 of Set 6 | hammerfest
# Processing Record 16 of Set 6 | ketchikan
# Processing Record 17 of Set 6 | oistins
# Processing Record 18 of Set 6 | bathsheba
# Processing Record 19 of Set 6 | nizwa
# Processing Record 20 of Set 6 | dmytrivka
# Processing Record 21 of Set 6 | deputatskiy
# Processing Record 22 of Set 6 | rio grande
# Processing Record 23 of Set 6 | grand river south east
# City not found! SKIPPNIG!
# Processing Record 24 of Set 6 | botwood
# Processing Record 25 of Set 6 | simao
# Processing Record 26 of Set 6 | hongjiang
# Processing Record 27 of Set 6 | norman wells
# Processing Record 28 of Set 6 | balabac
# Processing Record 29 of Set 6 | muros
# Processing Record 30 of Set 6 | saskylakh
# Processing Record 31 of Set 6 | vao
# Processing Record 32 of Set 6 | nioro
# Processing Record 33 of Set 6 | fortuna
# Processing Record 34 of Set 6 | tahe
# Processing Record 35 of Set 6 | acapulco
# Processing Record 36 of Set 6 | trairi
# Processing Record 37 of Set 6 | aksarka
# Processing Record 38 of Set 6 | nanortalik
# Processing Record 39 of Set 6 | chuy
# Processing Record 40 of Set 6 | maunabo
# Processing Record 41 of Set 6 | kilindoni
# Processing Record 42 of Set 6 | camopi
# Processing Record 43 of Set 6 | trinidad
# Processing Record 44 of Set 6 | lae
# Processing Record 45 of Set 6 | pilis
# Processing Record 46 of Set 6 | ponta do sol
# Processing Record 47 of Set 6 | khasan
# Processing Record 48 of Set 6 | collie
# Processing Record 49 of Set 6 | dombarovskiy
# Processing Record 50 of Set 6 | cockburn harbour
# City not found! SKIPPNIG!
# Processing Record 1 of Set 7 | moshi
# Processing Record 2 of Set 7 | honningsvag
# Processing Record 3 of Set 7 | georgiyevka
# Processing Record 4 of Set 7 | port keats
# Processing Record 5 of Set 7 | caruray
# Processing Record 6 of Set 7 | port-gentil
# Processing Record 7 of Set 7 | lazaro cardenas
# Processing Record 8 of Set 7 | coahuayana
# Processing Record 9 of Set 7 | lasa
# Processing Record 10 of Set 7 | santiago de cao
# Processing Record 11 of Set 7 | mashhad
# Processing Record 12 of Set 7 | sur
# Processing Record 13 of Set 7 | yambio
# Processing Record 14 of Set 7 | mandawar
# Processing Record 15 of Set 7 | esmeraldas
# Processing Record 16 of Set 7 | east london
# Processing Record 17 of Set 7 | isla del bosque
# Processing Record 18 of Set 7 | constitucion
# Processing Record 19 of Set 7 | sinjar
# Processing Record 20 of Set 7 | maxixe
# Processing Record 21 of Set 7 | ordynskoye
# Processing Record 22 of Set 7 | high level
# Processing Record 23 of Set 7 | provideniya
# Processing Record 24 of Set 7 | kemijarvi
# Processing Record 25 of Set 7 | alice
# Processing Record 26 of Set 7 | martapura
# Processing Record 27 of Set 7 | neuquen
# Processing Record 28 of Set 7 | lucea
# Processing Record 29 of Set 7 | ukiah
# Processing Record 30 of Set 7 | nishihara
# Processing Record 31 of Set 7 | ust-maya
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | juru
# Processing Record 34 of Set 7 | vanimo
# Processing Record 35 of Set 7 | masumbwe
# Processing Record 36 of Set 7 | manggar
# Processing Record 37 of Set 7 | liku
# Processing Record 38 of Set 7 | black river
# Processing Record 39 of Set 7 | gombe
# Processing Record 40 of Set 7 | perth
# Processing Record 41 of Set 7 | dudinka
# Processing Record 42 of Set 7 | tigil
# Processing Record 43 of Set 7 | beloha
# Processing Record 44 of Set 7 | nykobing
# City not found! SKIPPNIG!
# Processing Record 45 of Set 7 | ha giang
# Processing Record 46 of Set 7 | rocha
# Processing Record 47 of Set 7 | port elizabeth
# Processing Record 48 of Set 7 | orumiyeh
# Processing Record 49 of Set 7 | singaparna
# Processing Record 50 of Set 7 | pacifica
# Processing Record 1 of Set 8 | kokopo
# Processing Record 2 of Set 8 | geraldton
# Processing Record 3 of Set 8 | kulhudhuffushi
# Processing Record 4 of Set 8 | hami
# Processing Record 5 of Set 8 | santa maria
# Processing Record 6 of Set 8 | batemans bay
# Processing Record 7 of Set 8 | sao raimundo das mangabeiras
# Processing Record 8 of Set 8 | bambous virieux
# Processing Record 9 of Set 8 | cayenne
# Processing Record 10 of Set 8 | back mountain
# Processing Record 11 of Set 8 | husavik
# Processing Record 12 of Set 8 | pali
# Processing Record 13 of Set 8 | rusape
# Processing Record 14 of Set 8 | challapata
# Processing Record 15 of Set 8 | yarkovo
# Processing Record 16 of Set 8 | mergui
# City not found! SKIPPNIG!
# Processing Record 17 of Set 8 | iqaluit
# Processing Record 18 of Set 8 | umm kaddadah
# Processing Record 19 of Set 8 | xining
# Processing Record 20 of Set 8 | tabulbah
# City not found! SKIPPNIG!
# Processing Record 21 of Set 8 | mount gambier
# Processing Record 22 of Set 8 | chenzhou
# Processing Record 23 of Set 8 | tateyama
# Processing Record 24 of Set 8 | vila velha
# Processing Record 25 of Set 8 | humberto de campos
# Processing Record 26 of Set 8 | lincoln
# Processing Record 27 of Set 8 | buqayq
# City not found! SKIPPNIG!
# Processing Record 28 of Set 8 | polunochnoye
# Processing Record 29 of Set 8 | diffa
# Processing Record 30 of Set 8 | seoul
# Processing Record 31 of Set 8 | naze
# Processing Record 32 of Set 8 | bara
# Processing Record 33 of Set 8 | comodoro rivadavia
# Processing Record 34 of Set 8 | pevek
# Processing Record 35 of Set 8 | codrington
# Processing Record 36 of Set 8 | inuvik
# Processing Record 37 of Set 8 | nosy varika
# Processing Record 38 of Set 8 | frederiksberg
# Processing Record 39 of Set 8 | tuatapere
# Processing Record 40 of Set 8 | garm
# City not found! SKIPPNIG!
# Processing Record 41 of Set 8 | kolokani
# Processing Record 42 of Set 8 | esso
# Processing Record 43 of Set 8 | linao
# Processing Record 44 of Set 8 | gijon
# Processing Record 45 of Set 8 | beyneu
# Processing Record 46 of Set 8 | nemuro
# Processing Record 47 of Set 8 | kruisfontein
# Processing Record 48 of Set 8 | winnemucca
# Processing Record 49 of Set 8 | rungata
# City not found! SKIPPNIG!
# Processing Record 50 of Set 8 | pampa
# Processing Record 1 of Set 9 | tir pol
# City not found! SKIPPNIG!
# Processing Record 2 of Set 9 | saint-pierre
# Processing Record 3 of Set 9 | fort-shevchenko
# Processing Record 4 of Set 9 | santa isabel do rio negro
# Processing Record 5 of Set 9 | cabo san lucas
# Processing Record 6 of Set 9 | antofagasta
# Processing Record 7 of Set 9 | gondanglegi
# Processing Record 8 of Set 9 | mongo
# Processing Record 9 of Set 9 | guayaramerin
# Processing Record 10 of Set 9 | harper
# Processing Record 11 of Set 9 | camabatela
# Processing Record 12 of Set 9 | ulaanbaatar
# Processing Record 13 of Set 9 | luanda
# Processing Record 14 of Set 9 | lusambo
# Processing Record 15 of Set 9 | formoso do araguaia
# City not found! SKIPPNIG!
# Processing Record 16 of Set 9 | ostersund
# Processing Record 17 of Set 9 | lata
# Processing Record 18 of Set 9 | umzimvubu
# City not found! SKIPPNIG!
# Processing Record 19 of Set 9 | neiafu
# Processing Record 20 of Set 9 | lagoa
# Processing Record 21 of Set 9 | xai-xai
# Processing Record 22 of Set 9 | ossora
# Processing Record 23 of Set 9 | te anau
# Processing Record 24 of Set 9 | tuggurt
# City not found! SKIPPNIG!
# Processing Record 25 of Set 9 | the valley
# Processing Record 26 of Set 9 | maniitsoq
# Processing Record 27 of Set 9 | yar-sale
# Processing Record 28 of Set 9 | yerofey pavlovich
# Processing Record 29 of Set 9 | zyryanka
# Processing Record 30 of Set 9 | havelock
# Processing Record 31 of Set 9 | barrhead
# Processing Record 32 of Set 9 | kodiak
# Processing Record 33 of Set 9 | usinsk
# Processing Record 34 of Set 9 | elizabeth city
# Processing Record 35 of Set 9 | santa cruz
# Processing Record 36 of Set 9 | likasi
# Processing Record 37 of Set 9 | save
# Processing Record 38 of Set 9 | shache
# Processing Record 39 of Set 9 | naftah
# City not found! SKIPPNIG!
# Processing Record 40 of Set 9 | verkhoyansk
# Processing Record 41 of Set 9 | pangnirtung
# Processing Record 42 of Set 9 | yichang
# Processing Record 43 of Set 9 | aflu
# City not found! SKIPPNIG!
# Processing Record 44 of Set 9 | cap malheureux
# Processing Record 45 of Set 9 | tucupita
# Processing Record 46 of Set 9 | mayumba
# Processing Record 47 of Set 9 | sorland
# Processing Record 48 of Set 9 | tuysarkan
# City not found! SKIPPNIG!
# Processing Record 49 of Set 9 | puerto colombia
# Processing Record 50 of Set 9 | muli
# Processing Record 1 of Set 10 | cheuskiny
# City not found! SKIPPNIG!
# Processing Record 2 of Set 10 | necochea
# Processing Record 3 of Set 10 | taoudenni
# Processing Record 4 of Set 10 | porto novo
# Processing Record 5 of Set 10 | abnub
# Processing Record 6 of Set 10 | nelson bay
# Processing Record 7 of Set 10 | clarksburg
# Processing Record 8 of Set 10 | altamira
# Processing Record 9 of Set 10 | arrecife
# Processing Record 10 of Set 10 | sorong
# Processing Record 11 of Set 10 | along
# Processing Record 12 of Set 10 | marcona
# City not found! SKIPPNIG!
# Processing Record 13 of Set 10 | bokspits
# City not found! SKIPPNIG!
# Processing Record 14 of Set 10 | burica
# City not found! SKIPPNIG!
# Processing Record 15 of Set 10 | rawson
# Processing Record 16 of Set 10 | marzuq
# Processing Record 17 of Set 10 | krasnoyarsk-45
# City not found! SKIPPNIG!
# Processing Record 18 of Set 10 | utiroa
# City not found! SKIPPNIG!
# Processing Record 19 of Set 10 | tessalit
# Processing Record 20 of Set 10 | kuche
# City not found! SKIPPNIG!
# Processing Record 21 of Set 10 | lompoc
# Processing Record 22 of Set 10 | sao miguel do oeste
# City not found! SKIPPNIG!
# Processing Record 23 of Set 10 | bolu
# Processing Record 24 of Set 10 | hobyo
# Processing Record 25 of Set 10 | ola
# Processing Record 26 of Set 10 | le port
# Processing Record 27 of Set 10 | alta floresta
# Processing Record 28 of Set 10 | masvingo
# Processing Record 29 of Set 10 | nizhnyaya omka
# Processing Record 30 of Set 10 | porto-vecchio
# Processing Record 31 of Set 10 | gouyave
# Processing Record 32 of Set 10 | terrace bay
# Processing Record 33 of Set 10 | amalapuram
# Processing Record 34 of Set 10 | gorlice
# Processing Record 35 of Set 10 | leshukonskoye
# Processing Record 36 of Set 10 | ilulissat
# Processing Record 37 of Set 10 | oudtshoorn
# Processing Record 38 of Set 10 | davila
# Processing Record 39 of Set 10 | dzaoudzi
# Processing Record 40 of Set 10 | caceres
# Processing Record 41 of Set 10 | pietarsaari
# Processing Record 42 of Set 10 | jacareacanga
# Processing Record 43 of Set 10 | naranjos
# Processing Record 44 of Set 10 | rio negrinho
# Processing Record 45 of Set 10 | ciras
# City not found! SKIPPNIG!
# Processing Record 46 of Set 10 | rochegda
# Processing Record 47 of Set 10 | landang
# City not found! SKIPPNIG!
# Processing Record 48 of Set 10 | wanning
# Processing Record 49 of Set 10 | akdepe
# Processing Record 50 of Set 10 | wolmaranstad
# City not found! SKIPPNIG!
# Processing Record 1 of Set 11 | ambilobe
# Processing Record 2 of Set 11 | banjar
# Processing Record 3 of Set 11 | maragogi
# Processing Record 4 of Set 11 | la asuncion
# Processing Record 5 of Set 11 | mana
# Processing Record 6 of Set 11 | linxia
# Processing Record 7 of Set 11 | awbari
# Processing Record 8 of Set 11 | kifri
# Processing Record 9 of Set 11 | la ronge
# Processing Record 10 of Set 11 | sao joao da barra
# Processing Record 11 of Set 11 | yanam
# Processing Record 12 of Set 11 | thinadhoo
# Processing Record 13 of Set 11 | alenquer
# Processing Record 14 of Set 11 | kegayli
# City not found! SKIPPNIG!
# Processing Record 15 of Set 11 | mayo
# Processing Record 16 of Set 11 | kelowna
# Processing Record 17 of Set 11 | thessalon
# Processing Record 18 of Set 11 | basdiot
# Processing Record 19 of Set 11 | nanyang
# Processing Record 20 of Set 11 | egvekinot
# Processing Record 21 of Set 11 | vanavara
# Processing Record 22 of Set 11 | acarau
# Processing Record 23 of Set 11 | pittsburg
# Processing Record 24 of Set 11 | roma
# Processing Record 25 of Set 11 | lapeer
# Processing Record 26 of Set 11 | chara
# Processing Record 27 of Set 11 | sinazongwe
# Processing Record 28 of Set 11 | flinders
# Processing Record 29 of Set 11 | zhanaozen
# Processing Record 30 of Set 11 | puerto carreno
# Processing Record 31 of Set 11 | wahran
# City not found! SKIPPNIG!
# Processing Record 32 of Set 11 | mpanda
# Processing Record 33 of Set 11 | coihaique
# Processing Record 34 of Set 11 | qabis
# City not found! SKIPPNIG!
# Processing Record 35 of Set 11 | meulaboh
# Processing Record 36 of Set 11 | paita
# Processing Record 37 of Set 11 | bilma
# Processing Record 38 of Set 11 | tazmalt
# Processing Record 39 of Set 11 | zalantun
# Processing Record 40 of Set 11 | lalomanu
# City not found! SKIPPNIG!
# Processing Record 41 of Set 11 | magadan
# Processing Record 42 of Set 11 | tahta
# Processing Record 43 of Set 11 | san andres
# Processing Record 44 of Set 11 | hoopstad
# Processing Record 45 of Set 11 | puerto escondido
# Processing Record 46 of Set 11 | isangel
# Processing Record 47 of Set 11 | quime
# Processing Record 48 of Set 11 | ierapetra
# Processing Record 49 of Set 11 | dhidhdhoo
# Processing Record 50 of Set 11 | krasnovishersk
# Processing Record 1 of Set 12 | gola bazar
# Processing Record 2 of Set 12 | nuevitas
# Processing Record 3 of Set 12 | bambanglipuro
# Processing Record 4 of Set 12 | staraya poltavka
# Processing Record 5 of Set 12 | rawannawi
# City not found! SKIPPNIG!
# Processing Record 6 of Set 12 | plettenberg bay
# Processing Record 7 of Set 12 | malaut
# Processing Record 8 of Set 12 | kolondieba
# Processing Record 9 of Set 12 | ambunti
# Processing Record 10 of Set 12 | birjand
# Processing Record 11 of Set 12 | cabedelo
# Processing Record 12 of Set 12 | jiangyou
# Processing Record 13 of Set 12 | buin
# Processing Record 14 of Set 12 | lichuan
# Processing Record 15 of Set 12 | kinsale
# Processing Record 16 of Set 12 | fare
# Processing Record 17 of Set 12 | belle glade
# Processing Record 18 of Set 12 | mazyr
# Processing Record 19 of Set 12 | san quintin
# Processing Record 20 of Set 12 | texiguat
# Processing Record 21 of Set 12 | prince rupert
# Processing Record 22 of Set 12 | corrente
# Processing Record 23 of Set 12 | verkhnyaya inta
# Processing Record 24 of Set 12 | sarangani
# Processing Record 25 of Set 12 | oxapampa
# Processing Record 26 of Set 12 | fasa
# Processing Record 27 of Set 12 | chifeng
# Processing Record 28 of Set 12 | yuanping
# Processing Record 29 of Set 12 | nanakuli
# Processing Record 30 of Set 12 | maua
# Processing Record 31 of Set 12 | valdivia
# Processing Record 32 of Set 12 | ahipara
# Processing Record 33 of Set 12 | tarko-sale
# Processing Record 34 of Set 12 | saint-leu
# Processing Record 35 of Set 12 | anori
# Processing Record 36 of Set 12 | kysyl-syr
# Processing Record 37 of Set 12 | say
# Processing Record 38 of Set 12 | kabinda
# Processing Record 39 of Set 12 | barawe
# City not found! SKIPPNIG!
# Processing Record 40 of Set 12 | waynesboro
# Processing Record 41 of Set 12 | srednekolymsk
# Processing Record 42 of Set 12 | schwedt
# Processing Record 43 of Set 12 | ixtapa
# Processing Record 44 of Set 12 | andenes
# Processing Record 45 of Set 12 | huarmey
# Processing Record 46 of Set 12 | great yarmouth
# Processing Record 47 of Set 12 | denau
# City not found! SKIPPNIG!
# Processing Record 48 of Set 12 | geresk
# City not found! SKIPPNIG!
# Processing Record 49 of Set 12 | haapiti
# Processing Record 50 of Set 12 | bafoulabe
# Processing Record 1 of Set 13 | mwene-ditu
# Processing Record 2 of Set 13 | malindi
# Processing Record 3 of Set 13 | port hedland
# Processing Record 4 of Set 13 | moose factory
# Processing Record 5 of Set 13 | ust-uda
# Processing Record 6 of Set 13 | katobu
# Processing Record 7 of Set 13 | batagay-alyta
# Processing Record 8 of Set 13 | holme
# Processing Record 9 of Set 13 | ron phibun
# Processing Record 10 of Set 13 | chicama
# Processing Record 11 of Set 13 | beian
# Processing Record 12 of Set 13 | saint anthony
# Processing Record 13 of Set 13 | dukat
# Processing Record 14 of Set 13 | banda aceh
# Processing Record 15 of Set 13 | klaksvik
# Processing Record 16 of Set 13 | sigayevo
# Processing Record 17 of Set 13 | diego de almagro
# Processing Record 18 of Set 13 | kamakhyanagar
# Processing Record 19 of Set 13 | half moon bay
# Processing Record 20 of Set 13 | sonoita
# Processing Record 21 of Set 13 | port hardy
# Processing Record 22 of Set 13 | lolua
# City not found! SKIPPNIG!
# Processing Record 23 of Set 13 | jiaxing
# Processing Record 24 of Set 13 | hofn
# Processing Record 25 of Set 13 | escanaba
# Processing Record 26 of Set 13 | sao jose da coroa grande
# Processing Record 27 of Set 13 | alice springs
# Processing Record 28 of Set 13 | babstovo
# Processing Record 29 of Set 13 | caravelas
# Processing Record 30 of Set 13 | semporna
# Processing Record 31 of Set 13 | tias
# Processing Record 32 of Set 13 | abu samrah
# Processing Record 33 of Set 13 | kieta
# Processing Record 34 of Set 13 | thunder bay
# Processing Record 35 of Set 13 | agadez
# Processing Record 36 of Set 13 | dinsor
# City not found! SKIPPNIG!
# Processing Record 37 of Set 13 | ostrovnoy
# Processing Record 38 of Set 13 | peniche
# Processing Record 39 of Set 13 | is
# City not found! SKIPPNIG!
# Processing Record 40 of Set 13 | barra do bugres
# Processing Record 41 of Set 13 | tsiroanomandidy
# Processing Record 42 of Set 13 | kungurtug
# Processing Record 43 of Set 13 | yeehaw junction
# City not found! SKIPPNIG!
# Processing Record 44 of Set 13 | canakkale
# Processing Record 45 of Set 13 | kenai
# Processing Record 46 of Set 13 | mountain home
# Processing Record 47 of Set 13 | gladstone
# Processing Record 48 of Set 13 | nara
# Processing Record 49 of Set 13 | zeya
# Processing Record 50 of Set 13 | kang
# Processing Record 1 of Set 14 | al
# City not found! SKIPPNIG!
# Processing Record 2 of Set 14 | scarborough
# Processing Record 3 of Set 14 | brigantine
# Processing Record 4 of Set 14 | inderka
# Processing Record 5 of Set 14 | anqiu
# Processing Record 6 of Set 14 | lakes entrance
# Processing Record 7 of Set 14 | nakamura
# Processing Record 8 of Set 14 | trencianske teplice
# Processing Record 9 of Set 14 | jaltenango
# Processing Record 10 of Set 14 | muravlenko
# Processing Record 11 of Set 14 | vernon
# ------------------------
# Completed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictionary to keep data 
weather_data = {
     "City": cities_list,
     "Cloudiness": cloudiness,
     "Country": country,
     "Date": date,
     "Humidity": humidity,
     "Lat": lat,
     "Lng": lng,
     "Max Temp": max_temp,
     "Wind Speed": wind_speed    
 }

# Create the data frame and print .head()
weather_df = pd.DataFrame(weather_data)
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0     Hirara          75      JP  1651960564        94  24.8000  125.2833
# 1     Anadyr          40      RU  1651960564        74  64.7500  177.4833
# 2   Khatanga          98      RU  1651960565       100  71.9667  102.5000
# 3    Mataura         100      NZ  1651960520        99 -46.1927  168.8643
# 4  Cape Town           0      ZA  1651960435        83 -33.9258   18.4232
#
#    Max Temp  Wind Speed
# 0     75.47        1.14
# 1     34.30       13.42
# 2     -1.21        6.89
# 3     57.47        2.35
# 4     57.90       11.50

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a scatter plot
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker = "o", facecolor = "red", edgecolor="black")

plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))

plt.xlabel("Latitude")

plt.ylabel("Max Temprature (F)")

plt.grid()

plt.savefig("output_data/cityvsmaxtemp1.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a scatter plot
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker = "o", facecolor = "grey", edgecolor="black")

plt.xlabel("Latitude")

plt.ylabel("Humidity (%)")

plt.title("City Latitude vs Humidity (%s)" % time.strftime("%x"))

plt.grid()

plt.savefig("output_data/latvshumidity2.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker = "o", facecolor = "green", edgecolor="black")

plt.xlabel("Latitude")

plt.ylabel("Cloudiness (%)")

plt.title("City Latitude vs Cloudiness (%s)" % time.strftime("%x"))

plt.grid()

plt.savefig("output_data/latvscloudiness3.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker = "o", facecolor = "purple", edgecolor="black")

plt.xlabel("Latitude")

plt.ylabel("Speed (mph)")

plt.title("City Latitude vs Wind Speed (%s)" % time.strftime("%x"))

plt.grid()

plt.savefig("output_data/latvswindspeed4.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create dataframes
northern_df = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = -0.92x + 94.64
# The r-squared is: -0.8834170579531845

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.54x + 79.19
# The r-squared is: 0.7009165544809856

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.19x + 60.91
# The r-squared is: 0.16714333541300522

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.27x + 82.86
# The r-squared is: 0.2441975507057612

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.05x + 56.02
# The r-squared is: 0.026449133147573498

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.12x + 51.75
# The r-squared is: 0.04324752438950419

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.03x + 7.47
# The r-squared is: 0.09303930315495469

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = -0.04x + 5.58
# The r-squared is: -0.12571681622200417
